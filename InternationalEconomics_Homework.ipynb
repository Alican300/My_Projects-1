# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
df_USA = pd.read_excel("USA-Partner.xlsx", sheet_name="Partner")
df_USA.head(10)
# Out:
#    Reporter Name          Partner Name  Year Trade Flow  \
# 0  United States                 Aruba  2022     Import
# 1  United States           Afghanistan  2022     Import
# 2  United States                Angola  2022     Import
# 3  United States               Anguila  2022     Import
# 4  United States               Albania  2022     Import
# 5  United States               Andorra  2022     Import
# 6  United States  United Arab Emirates  2022     Import
# 7  United States             Argentina  2022     Import
# 8  United States               Armenia  2022     Import
# 9  United States       Fr. So. Ant. Tr  2022     Import
#
#    No Of imported HS6 digit Products  Import Share in Total Products (%)  \
# 0                                 58                                   1
# 1                                153                                   3
# 2                                 25                                   1
# ...

# %%
df_TUR = pd.read_excel("TUR-Partner.xlsx", sheet_name="Partner")
df_GER=pd.read_excel("GER-Partner.xlsx", sheet_name="Partner")
df_ARG=pd.read_excel("ARG-Partner.xlsx", sheet_name="Partner")
df_BRA=pd.read_excel("BRA-Partner.xlsx", sheet_name="Partner")
df_RUS=pd.read_excel("RUS-Partner.xlsx", sheet_name="Partner")
df_MEX=pd.read_excel("MEX-Partner.xlsx", sheet_name="Partner")
df_FRA=pd.read_excel("FRA-Partner.xlsx", sheet_name="Partner")
df_ENG=pd.read_excel("ENG-Partner.xlsx", sheet_name="Partner")
df_JAP=pd.read_excel("JAP-Partner.xlsx", sheet_name="Partner")

# %%
df_USA[["Reporter Name","Partner Name","Year","Trade Flow","Import (US$ Thousand)"]].sort_values(by="Import (US$ Thousand)",ascending=False).reset_index(drop=True).head(10)
# Out:
#    Reporter Name               Partner Name  Year Trade Flow  \
# 0  United States                      World  2022     Import
# 1  United States        East Asia & Pacific  2022     Import
# 2  United States      Europe & Central Asia  2022     Import
# 3  United States  Latin America & Caribbean  2022     Import
# 4  United States                      China  2022     Import
# 5  United States                     Mexico  2022     Import
# 6  United States              North America  2022     Import
# 7  United States                     Canada  2022     Import
# 8  United States                      Japan  2022     Import
# 9  United States                    Germany  2022     Import
#
#    Import (US$ Thousand)
# 0          3,372,902,166
# 1          1,235,546,151
# 2            744,048,192
# 3            616,786,657
# 4            575,688,091
# 5            459,177,656
# 6            446,638,452
# 7            446,623,934
# 8            154,445,162
# 9            150,408,499

# %%
df_USA=df_USA[["Reporter Name","Partner Name","Year","Trade Flow","Import (US$ Thousand)"]].sort_values(by="Import (US$ Thousand)",ascending=False).reset_index(drop=True).head(10)

# %%
country_list=[df_USA,df_GER,df_JAP]
country_names=["United States","Germany","Japan"]

# %%
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(15,5))
for i,col, in enumerate(country_list):
    sns.barplot(data=col,x="Import (US$ Thousand)",y="Partner Name",ax=ax[i])
    plt.suptitle("Import of Countries",fontsize=13)
    ax[i].set_title(country_names[i])
    ax[i].set_ylabel("Countries")
    ax[i].set_xlabel("İmport(US$ Thousand)")

plt.tight_layout()
plt.show()

# %%
country_list_2=[df_ARG,df_BRA,df_MEX]
country_names_2=["Argentina","Brazil","Mexico"]

# %%
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(15,5))
for i,col, in enumerate(country_list_2):
    sns.barplot(data=col,x="Import (US$ Thousand)",y="Partner Name",ax=ax[i])
    plt.suptitle("Import of Countries",fontsize=13)
    ax[i].set_title(country_names_2[i])
    ax[i].set_ylabel("Countries")
    ax[i].set_xlabel("Import(US$ Thousand)")

plt.tight_layout()
plt.show()

# %%
country_list_3=[df_FRA,df_ENG,df_RUS]
country_names_3=["France","United Kingdom","Russia"]

# %%
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(15,5))
for i,col, in enumerate(country_list_3):
    sns.barplot(data=col,x="Import (US$ Thousand)",y="Partner Name",ax=ax[i])
    plt.suptitle("Import of Countries",fontsize=13)
    ax[i].set_title(country_names_3[i])
    ax[i].set_ylabel("Countries")
    ax[i].set_xlabel("Import(US$ Thousand)")

plt.tight_layout()
plt.show()

# %%
df_TUR=df_TUR[["Reporter Name","Partner Name","Year","Trade Flow","Import (US$ Thousand)"]].sort_values(by="Import (US$ Thousand)",ascending=False).reset_index(drop=True).head(10)

# %%
sns.barplot(data=df_TUR,x="Import (US$ Thousand)",y="Partner Name")
plt.title("Import of Turkiye")
plt.xlabel("Import(US$ Thousand)")
plt.ylabel("Countires")
plt.show()
